# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %%
# !pip install tensorflow==2.16.2
# Out:
# Collecting tensorflow==2.16.2
#   Downloading tensorflow-2.16.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting absl-py>=1.0.0 (from tensorflow==2.16.2)
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow==2.16.2)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=23.5.26 (from tensorflow==2.16.2)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow==2.16.2)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow==2.16.2)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=3.10.0 (from tensorflow==2.16.2)
#   Downloading h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Collecting libclang>=13.0.0 (from tensorflow==2.16.2)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting ml-dtypes~=0.3.1 (from tensorflow==2.16.2)
#   Downloading ml_dtypes-0.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow==2.16.2)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (24.2)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow==2.16.2)
#   Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow==2.16.2)
#   Downloading termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (4.12.2)
# Collecting wrapt>=1.11.0 (from tensorflow==2.16.2)
#   Downloading wrapt-1.17.3-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (6.4 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow==2.16.2)
#   Downloading grpcio-1.74.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow==2.16.2)
#   Downloading tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.0.0 (from tensorflow==2.16.2)
#   Downloading keras-3.11.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting numpy<2.0.0,>=1.26.0 (from tensorflow==2.16.2)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow==2.16.2) (0.45.1)
# Collecting rich (from keras>=3.0.0->tensorflow==2.16.2)
#   Downloading rich-14.1.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.0.0->tensorflow==2.16.2)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.0.0->tensorflow==2.16.2)
#   Downloading optree-0.17.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (33 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (2024.12.14)
# Collecting markdown>=2.6.8 (from tensorboard<2.17,>=2.16->tensorflow==2.16.2)
#   Downloading markdown-3.9-py3-none-any.whl.metadata (5.1 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.17,>=2.16->tensorflow==2.16.2)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.17,>=2.16->tensorflow==2.16.2)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow==2.16.2) (3.0.2)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.0.0->tensorflow==2.16.2)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow==2.16.2)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.16.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (590.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.8/590.8 MB 9.2 MB/s eta 0:00:00:00:0100:01
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.74.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 45.1 MB/s eta 0:00:00
# Downloading h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 49.5 MB/s eta 0:00:00
# Downloading keras-3.11.3-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 61.4 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 48.3 MB/s eta 0:00:00:00:01
# Downloading ml_dtypes-0.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 445.8 kB/s eta 0:00:00a 0:00:01
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 39.8 MB/s eta 0:00:00:00:01
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 55.9 MB/s eta 0:00:00
# Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Downloading wrapt-1.17.3-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (88 kB)
# Downloading markdown-3.9-py3-none-any.whl (107 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 57.5 MB/s eta 0:00:00
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.17.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (408 kB)
# Downloading rich-14.1.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, werkzeug, termcolor, tensorboard-data-server, protobuf, optree, opt-einsum, numpy, mdurl, markdown, grpcio, google-pasta, gast, astunparse, absl-py, tensorboard, ml-dtypes, markdown-it-py, h5py, rich, keras, tensorflow
# Successfully installed absl-py-2.3.1 astunparse-1.6.3 flatbuffers-25.2.10 gast-0.6.0 google-pasta-0.2.0 grpcio-1.74.0 h5py-3.14.0 keras-3.11.3 libclang-18.1.1 markdown-3.9 markdown-it-py-4.0.0 mdurl-0.1.2 ml-dtypes-0.3.2 namex-0.1.0 numpy-1.26.4 opt-einsum-3.4.0 optree-0.17.0 protobuf-4.25.8 rich-14.1.0 tensorboard-2.16.2 tensorboard-data-server-0.7.2 tensorflow-2.16.2 termcolor-3.1.0 werkzeug-3.1.3 wrapt-1.17.3

# %%
import numpy as np 
from tensorflow.keras.datasets import mnist 

# Load the dataset 
(x_train, _), (x_test, _) = mnist.load_data() 

# Normalize the pixel values 
x_train = x_train.astype('float32') / 255. 
x_test = x_test.astype('float32') / 255. 

# Flatten the images 
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:]))) 
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
# Out:
# 2025-09-10 13:57:26.911927: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-10 13:57:26.913154: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-09-10 13:57:26.917686: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-09-10 13:57:26.931119: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-09-10 13:57:26.958839: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-09-10 13:57:26.958917: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-09-10 13:57:26.979285: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-09-10 13:57:28.157126: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.models import Model 
from tensorflow.keras.layers import Input, Dense 

# Encoder 
input_layer = Input(shape=(784,)) 
encoded = Dense(64, activation='relu')(input_layer) 

# Bottleneck 
bottleneck = Dense(32, activation='relu')(encoded) 

# Decoder 
decoded = Dense(64, activation='relu')(bottleneck) 
output_layer = Dense(784, activation='sigmoid')(decoded) 

# Autoencoder model 
autoencoder = Model(input_layer, output_layer) 

# Compile the model 
autoencoder.compile(optimizer='adam', loss='binary_crossentropy') 

# Summary of the model 
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        50,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 784)            │        50,960 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 105,392 (411.69 KB)
#  Trainable params: 105,392 (411.69 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
autoencoder.fit(
    x_train, x_train,  
    epochs=25,  
    batch_size=256,  
    shuffle=True,  
    validation_data=(x_test, x_test)
)
# Out:
# Epoch 1/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - loss: 0.2587 - val_loss: 0.1811
# Epoch 2/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.1648 - val_loss: 0.1499
# Epoch 3/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.1429 - val_loss: 0.1339
# Epoch 4/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.1297 - val_loss: 0.1249
# Epoch 5/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1228 - val_loss: 0.1187
# Epoch 6/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.1176 - val_loss: 0.1135
# Epoch 7/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1132 - val_loss: 0.1104
# Epoch 8/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.1102 - val_loss: 0.1077
# Epoch 9/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1081 - val_loss: 0.1057
# Epoch 10/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1063 - val_loss: 0.1041
# Epoch 11/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1046 - val_loss: 0.1025
# Epoch 12/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.1034 - val_loss: 0.1018
# Epoch 13/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1025 - val_loss: 0.1006
# Epoch 14/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1016 - val_loss: 0.0999
# Epoch 15/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1007 - val_loss: 0.0988
# Epoch 16/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0999 - val_loss: 0.0982
# Epoch 17/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0991 - val_loss: 0.0974
# Epoch 18/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0984 - val_loss: 0.0968
# Epoch 19/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0977 - val_loss: 0.0963
# Epoch 20/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0972 - val_loss: 0.0957
# Epoch 21/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0967 - val_loss: 0.0951
# Epoch 22/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0962 - val_loss: 0.0948
# Epoch 23/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0958 - val_loss: 0.0945
# Epoch 24/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0955 - val_loss: 0.0944
# Epoch 25/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0951 - val_loss: 0.0944

# %%
# !pip install matplotlib==3.9.2
# Out:
# Collecting matplotlib==3.9.2
#   Downloading matplotlib-3.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib==3.9.2)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib==3.9.2)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib==3.9.2)
#   Downloading fonttools-4.59.2-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (109 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib==3.9.2)
#   Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.2) (24.2)
# Collecting pillow>=8 (from matplotlib==3.9.2)
#   Downloading pillow-11.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib==3.9.2)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.2) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib==3.9.2) (1.17.0)
# Downloading matplotlib-3.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 111.4 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.59.2-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 154.5 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 92.7 MB/s eta 0:00:00
# Downloading pillow-11.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 147.6 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.59.2 kiwisolver-1.4.9 matplotlib-3.9.2 pillow-11.3.0 pyparsing-3.2.3

# %%
import matplotlib.pyplot as plt 

# Predict the test data 
reconstructed = autoencoder.predict(x_test) 

# Visualize the results 
n = 10  # Number of digits to display 
plt.figure(figsize=(20, 4)) 

for i in range(n): 
    # Display original 
    ax = plt.subplot(2, n, i + 1) 
    plt.imshow(x_test[i].reshape(28, 28)) 
    plt.gray() 
    ax.get_xaxis().set_visible(False) 
    ax.get_yaxis().set_visible(False) 

    # Display reconstruction 
    ax = plt.subplot(2, n, i + 1 + n) 
    plt.imshow(reconstructed[i].reshape(28, 28)) 
    plt.gray() 
    ax.get_xaxis().set_visible(False) 
    ax.get_yaxis().set_visible(False) 

plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
# Freeze all layers of the autoencoder
for layer in autoencoder.layers:
    layer.trainable = False

# %%
# Check trainable status of each layer
for i, layer in enumerate(autoencoder.layers):
    print(f"Layer {i}: {layer.name}, Trainable = {layer.trainable}")
# Out:
# Layer 0: input_layer, Trainable = False
# Layer 1: dense, Trainable = False
# Layer 2: dense_1, Trainable = False
# Layer 3: dense_2, Trainable = False
# Layer 4: dense_3, Trainable = False

# %%
# Unfreeze the top layers of the encoder
for layer in autoencoder.layers[-4:]: 
    layer.trainable = True 

# Compile the model again
autoencoder.compile(optimizer='adam', loss='binary_crossentropy') 

# Train the model again
autoencoder.fit(x_train, x_train,  
                epochs=10,  
                batch_size=256,  
                shuffle=True,  
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - loss: 0.0954 - val_loss: 0.0936
# Epoch 2/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0946 - val_loss: 0.0934
# Epoch 3/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0945 - val_loss: 0.0934
# Epoch 4/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0942 - val_loss: 0.0932
# Epoch 5/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0941 - val_loss: 0.0928
# Epoch 6/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0939 - val_loss: 0.0928
# Epoch 7/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0937 - val_loss: 0.0926
# Epoch 8/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0935 - val_loss: 0.0923
# Epoch 9/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0934 - val_loss: 0.0924
# Epoch 10/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0932 - val_loss: 0.0921

# %%
import numpy as np
import matplotlib.pyplot as plt

# Add noise to the data
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# Train the autoencoder with noisy data
autoencoder.fit(
    x_train_noisy, x_train,
    epochs=20,
    batch_size=512,
    shuffle=True,
    validation_data=(x_test_noisy, x_test)
)

# Denoise the test images
reconstructed_noisy = autoencoder.predict(x_test_noisy)

# Visualize the results
n = 10  # Number of digits to display
plt.figure(figsize=(20, 6))
for i in range(n):
    # Display noisy images
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    # Display denoised images
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(reconstructed_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display original images
    ax = plt.subplot(3, n, i + 1 + 2 * n)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()
# Out:
# Epoch 1/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.1683 - val_loss: 0.1420
# Epoch 2/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.1383 - val_loss: 0.1333
# Epoch 3/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.1322 - val_loss: 0.1294
# Epoch 4/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.1291 - val_loss: 0.1272
# Epoch 5/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.1273 - val_loss: 0.1258
# Epoch 6/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.1261 - val_loss: 0.1251
# Epoch 7/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.1253 - val_loss: 0.1242
# Epoch 8/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.1247 - val_loss: 0.1242
# Epoch 9/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.1242 - val_loss: 0.1233
# Epoch 10/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.1237 - val_loss: 0.1229
# Epoch 11/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.1234 - val_loss: 0.1230
# Epoch 12/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.1233 - val_loss: 0.1229
# Epoch 13/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.1230 - val_loss: 0.1225
# Epoch 14/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.1228 - val_loss: 0.1226
# Epoch 15/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.1227 - val_loss: 0.1221
# Epoch 16/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.1224 - val_loss: 0.1221
# Epoch 17/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.1223 - val_loss: 0.1218
# Epoch 18/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.1221 - val_loss: 0.1218
# Epoch 19/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.1220 - val_loss: 0.1222
# Epoch 20/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.1220 - val_loss: 0.1223
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
# Define and train three different autoencoders with varying bottleneck sizes
bottleneck_sizes = [16, 32, 64]
autoencoders = []

for size in bottleneck_sizes:
    # Encoder
    input_layer = Input(shape=(784,))
    encoded = Dense(64, activation='relu')(input_layer)
    bottleneck = Dense(size, activation='relu')(encoded)

    # Decoder
    decoded = Dense(64, activation='relu')(bottleneck)
    output_layer = Dense(784, activation='sigmoid')(decoded)
    # Autoencoder model
    autoencoder = Model(input_layer, output_layer)
    autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
    autoencoder.fit(
        x_train,
        x_train,
        epochs=20,
        batch_size=256,
        shuffle=True,
        validation_data=(x_test, x_test)
    )
    autoencoders.append(autoencoder)

# Evaluate and compare the models
for i, size in enumerate(bottleneck_sizes):
    loss = autoencoders[i].evaluate(x_test, x_test)
    print(f'Bottleneck size {size} - Test loss: {loss}')
# Out:
# Epoch 1/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - loss: 0.2655 - val_loss: 0.1798
# Epoch 2/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.1620 - val_loss: 0.1485
# Epoch 3/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1428 - val_loss: 0.1359
# Epoch 4/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1346 - val_loss: 0.1309
# Epoch 5/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1306 - val_loss: 0.1275
# Epoch 6/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1270 - val_loss: 0.1242
# Epoch 7/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1245 - val_loss: 0.1220
# Epoch 8/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.1229 - val_loss: 0.1208
# Epoch 9/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.1216 - val_loss: 0.1195
# Epoch 10/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1205 - val_loss: 0.1185
# Epoch 11/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1196 - val_loss: 0.1178
# Epoch 12/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1188 - val_loss: 0.1169
# Epoch 13/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1180 - val_loss: 0.1165
# Epoch 14/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.1173 - val_loss: 0.1156
# Epoch 15/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1166 - val_loss: 0.1150
# Epoch 16/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1160 - val_loss: 0.1143
# Epoch 17/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1154 - val_loss: 0.1139
# Epoch 18/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1149 - val_loss: 0.1132
# Epoch 19/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.1144 - val_loss: 0.1130
# Epoch 20/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1140 - val_loss: 0.1128
# Epoch 1/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - loss: 0.2553 - val_loss: 0.1747
# Epoch 2/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1588 - val_loss: 0.1440
# Epoch 3/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1370 - val_loss: 0.1293
# Epoch 4/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.1249 - val_loss: 0.1188
# Epoch 5/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.1172 - val_loss: 0.1130
# Epoch 6/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1126 - val_loss: 0.1090
# Epoch 7/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1091 - val_loss: 0.1063
# Epoch 8/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1069 - val_loss: 0.1045
# Epoch 9/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1052 - val_loss: 0.1030
# Epoch 10/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1037 - val_loss: 0.1017
# Epoch 11/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1023 - val_loss: 0.1004
# Epoch 12/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1009 - val_loss: 0.0989
# Epoch 13/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0997 - val_loss: 0.0979
# Epoch 14/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0987 - val_loss: 0.0969
# Epoch 15/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0978 - val_loss: 0.0962
# Epoch 16/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0971 - val_loss: 0.0959
# Epoch 17/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0965 - val_loss: 0.0951
# Epoch 18/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0961 - val_loss: 0.0946
# Epoch 19/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0957 - val_loss: 0.0944
# Epoch 20/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0953 - val_loss: 0.0938
# Epoch 1/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - loss: 0.2461 - val_loss: 0.1664
# Epoch 2/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.1491 - val_loss: 0.1320
# Epoch 3/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1262 - val_loss: 0.1185
# Epoch 4/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1160 - val_loss: 0.1106
# Epoch 5/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1096 - val_loss: 0.1058
# Epoch 6/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1056 - val_loss: 0.1028
# Epoch 7/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1022 - val_loss: 0.0993
# Epoch 8/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0995 - val_loss: 0.0973
# Epoch 9/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0974 - val_loss: 0.0952
# Epoch 10/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0960 - val_loss: 0.0940
# Epoch 11/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0946 - val_loss: 0.0928
# Epoch 12/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0936 - val_loss: 0.0919
# Epoch 13/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0926 - val_loss: 0.0913
# Epoch 14/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0917 - val_loss: 0.0903
# Epoch 15/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0909 - val_loss: 0.0898
# Epoch 16/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0901 - val_loss: 0.0888
# Epoch 17/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0894 - val_loss: 0.0880
# Epoch 18/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0887 - val_loss: 0.0873
# Epoch 19/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0880 - val_loss: 0.0869
# Epoch 20/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0876 - val_loss: 0.0867
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1128
# Bottleneck size 16 - Test loss: 0.112827830016613
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0938
# Bottleneck size 32 - Test loss: 0.09384894371032715
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0867
# Bottleneck size 64 - Test loss: 0.08666632324457169

# %%
from tensorflow.keras.regularizers import l2 

# Encoder with L2 regularization 
input_layer = Input(shape=(784,)) 
encoded = Dense(64, activation='relu', kernel_regularizer=l2(0.01))(input_layer) 
bottleneck = Dense(32, activation='relu', kernel_regularizer=l2(0.01))(encoded) 

# Decoder with L2 regularization 
decoded = Dense(64, activation='relu', kernel_regularizer=l2(0.01))(bottleneck) 
output_layer = Dense(784, activation='sigmoid', kernel_regularizer=l2(0.01))(decoded) 

# Autoencoder model with L2 regularization 
autoencoder_regularized = Model(input_layer, output_layer) 
autoencoder_regularized.compile(optimizer='adam', loss='binary_crossentropy') 

# Train the model 
autoencoder_regularized.fit(x_train, x_train, epochs=50, batch_size=256, shuffle=True, validation_data=(x_test, x_test)) 

# Evaluate the model 
loss = autoencoder_regularized.evaluate(x_test, x_test) 
print(f'Regularized Autoencoder - Test loss: {loss}')
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - loss: 0.9885 - val_loss: 0.4422
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.4129 - val_loss: 0.3966
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.3897 - val_loss: 0.3815
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.3750 - val_loss: 0.3674
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.3614 - val_loss: 0.3550
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.3500 - val_loss: 0.3449
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.3410 - val_loss: 0.3368
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.3334 - val_loss: 0.3298
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.3267 - val_loss: 0.3237
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.3205 - val_loss: 0.3178
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.3148 - val_loss: 0.3122
# Epoch 12/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.3095 - val_loss: 0.3071
# Epoch 13/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.3045 - val_loss: 0.3021
# Epoch 14/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.3000 - val_loss: 0.2977
# Epoch 15/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.2956 - val_loss: 0.2937
# Epoch 16/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.2916 - val_loss: 0.2898
# Epoch 17/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.2880 - val_loss: 0.2862
# Epoch 18/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.2848 - val_loss: 0.2832
# Epoch 19/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.2819 - val_loss: 0.2805
# Epoch 20/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.2794 - val_loss: 0.2781
# Epoch 21/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.2772 - val_loss: 0.2760
# Epoch 22/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.2753 - val_loss: 0.2746
# Epoch 23/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.2737 - val_loss: 0.2727
# Epoch 24/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.2723 - val_loss: 0.2716
# Epoch 25/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.2711 - val_loss: 0.2704
# Epoch 26/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.2701 - val_loss: 0.2694
# Epoch 27/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.2693 - val_loss: 0.2686
# Epoch 28/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.2685 - val_loss: 0.2682
# Epoch 29/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.2678 - val_loss: 0.2675
# Epoch 30/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.2672 - val_loss: 0.2670
# Epoch 31/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.2667 - val_loss: 0.2662
# Epoch 32/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.2663 - val_loss: 0.2657
# Epoch 33/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.2659 - val_loss: 0.2656
# Epoch 34/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.2656 - val_loss: 0.2653
# Epoch 35/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.2653 - val_loss: 0.2648
# Epoch 36/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.2650 - val_loss: 0.2646
# Epoch 37/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.2648 - val_loss: 0.2646
# Epoch 38/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.2646 - val_loss: 0.2645
# Epoch 39/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.2644 - val_loss: 0.2641
# Epoch 40/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.2643 - val_loss: 0.2641
# Epoch 41/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.2642 - val_loss: 0.2638
# Epoch 42/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.2640 - val_loss: 0.2639
# Epoch 43/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.2639 - val_loss: 0.2638
# Epoch 44/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.2638 - val_loss: 0.2634
# Epoch 45/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.2638 - val_loss: 0.2635
# Epoch 46/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.2637 - val_loss: 0.2634
# Epoch 47/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.2636 - val_loss: 0.2631
# Epoch 48/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.2635 - val_loss: 0.2633
# Epoch 49/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.2634 - val_loss: 0.2631
# Epoch 50/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.2634 - val_loss: 0.2630
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2630
# Regularized Autoencoder - Test loss: 0.26301491260528564

# %%
import matplotlib.pyplot as plt 

# Extract the encoder part of the autoencoder 
encoder_model = Model(input_layer, bottleneck) 

# Encode the test data 
encoded_imgs = encoder_model.predict(x_test) 

# Visualize the first two dimensions of the encoded features 
plt.figure(figsize=(10, 8)) 
plt.scatter(encoded_imgs[:, 0], encoded_imgs[:, 1], c='blue', alpha=0.5) 
plt.title('Encoded Features - First Two Dimensions') 
plt.xlabel('Encoded Feature 1') 
plt.ylabel('Encoded Feature 2') 
plt.show()
